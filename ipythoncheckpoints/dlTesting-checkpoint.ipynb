# %%
from oof1 import DataLoader
from glob import glob
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from scipy.misc import imread

# %%
DL = DataLoader("brick",(256,256))
print(DL.dataset_name)
# Out:
# brick

# %%
A,B = DL.load_data(1,False)

# %%
import cv2

# %%
img = cv2.imread('datasets/input/model inputs/screen_0.png')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
imgres = cv2.resize(img,(256,256))

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(imgres)
#plt.imshow(A[0]/2 + 0.5)

# %%
import imageio

# %%
img_  = imageio.imread('datasets/input/brick/train/screen_0.png')

# %%
plt.imshow(img_)
