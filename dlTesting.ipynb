# %%
from data_loader1 import DataLoader
from glob import glob
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from scipy.misc import imread

# %%
DL = DataLoader("brick",(256,256))
print(DL.dataset_name)
# Out:
# brick

# %%
A,B = DL.load_data(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-7673957e9eb8> in <module>
# ----> 1 A,B = DL.load_data(10)
#
# ~\Desktop\pix2pix\data_loader1.py in load_data(self, batch_size, is_testing)
#      24         imgs_B = []
#      25         for x in range(batch_size):
# ---> 26             i = random.randint(0, len(path_in) - 1)
#      27             img_in = self.imread(path_in[i])
#      28             img_out = self.imread(path_out[i])
#
# NameError: name 'random' is not defined

# %%
import cv2
plt.imshow(B[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for i in range(A.shape[0]):
    fig = plt.figure(figsize=(8, 8))
    img = B[i] / 2 + 0.5
    fig.add_subplot(1, 2, 1)
    plt.imshow(img)
    fig.add_subplot(1, 2, 2)
    img = A[i] / 2 + 0.5
    plt.imshow(img)

# %%
img = cv2.imread('datasets/input/model inputs/screen_500.png')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
imgres = cv2.resize(img,(256,256))

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(imgres)
#plt.imshow(A[0]/2 + 0.5)

# %%
import imageio

# %%
img_  = imageio.imread('datasets/input/brick/train/screen_0.png')

# %%
plt.imshow(img_)
